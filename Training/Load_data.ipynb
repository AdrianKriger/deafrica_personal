# %%
# %matplotlib inline

import sys
import datacube

sys.path.append("../Scripts")
from deafrica_plotting import rgb
from deafrica_plotting import display_map

# %%
dc = datacube.Datacube(app="Load_data")

# %%
x = (39.20, 39.37)
y = (-6.90, -6.70)

display_map(x, y)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
landsat_ds = dc.load(
    product="ls8_usgs_sr_scene",
    x=x,
    y=y,
    time=("2018-01-01", "2018-12-31"),
    output_crs="EPSG:6933",
    resolution=(-30,30),
    group_by="solar_day",
    measurements=["red", "green", "blue"])

# %%
landsat_ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 21, x: 548, y: 845)
# Coordinates:
#   * time         (time) datetime64[ns] 2018-01-15T07:32:04.349192 ... 2018-12...
#   * y            (y) float64 -8.529e+05 -8.529e+05 ... -8.781e+05 -8.782e+05
#   * x            (x) float64 3.782e+06 3.782e+06 ... 3.799e+06 3.799e+06
#     spatial_ref  int32 6933
# Data variables:
#     red          (time, y, x) int16 -9999 -9999 -9999 -9999 ... 6682 6323 6968
#     green        (time, y, x) int16 -9999 -9999 -9999 -9999 ... 6519 6216 6809
#     blue         (time, y, x) int16 -9999 -9999 -9999 -9999 ... 6338 6070 6696
# Attributes:
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref

# %%
rgb(landsat_ds, bands=['red', 'green', 'blue'],
   index=2, size=10)

# %%
sentinel2_ds = dc.load(
    product="s2_l2a",
    x=x,
    y=y,
    time=("2018-01-01", "2018-12-31"),
    output_crs="EPSG:6933",
    resolution=(-10,10),
    group_by="solar_day",
    measurements=["red", "green", "blue"])

# %%
sentinel2_ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 71, x: 1641, y: 2535)
# Coordinates:
#   * time         (time) datetime64[ns] 2018-01-01T07:50:08 ... 2018-12-27T07:...
#   * y            (y) float64 -8.528e+05 -8.529e+05 ... -8.782e+05 -8.782e+05
#   * x            (x) float64 3.782e+06 3.782e+06 ... 3.799e+06 3.799e+06
#     spatial_ref  int32 6933
# Data variables:
#     red          (time, y, x) uint16 3066 3528 3914 4188 ... 1390 1204 1430 1644
#     green        (time, y, x) uint16 3322 3726 4124 4388 ... 1322 1242 1424 1598
#     blue         (time, y, x) uint16 3342 3748 4136 4376 ... 971 859 1072 1206
# Attributes:
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref

# %%
rgb(sentinel2_ds, bands=['red', 'green', 'blue'],
   index=2, size=10)

# %%
session2Quiz_ds = dc.load(
    product="s2_l2a",
    x=(35.393, 35.413),
    y=(0.05, 0.07),
    time=('2019-01-01', '2019-01-31'),
    output_crs="EPSG:6933",
    resolution=(-10,10),
    group_by="solar_day",
    measurements=["red", "green", "blue"])

# %%
session2Quiz_ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 6, x: 194, y: 257)
# Coordinates:
#   * time         (time) datetime64[ns] 2019-01-02T08:09:50 ... 2019-01-27T08:...
#   * y            (y) float64 8.935e+03 8.925e+03 ... 6.385e+03 6.375e+03
#   * x            (x) float64 3.415e+06 3.415e+06 ... 3.417e+06 3.417e+06
#     spatial_ref  int32 6933
# Data variables:
#     red          (time, y, x) uint16 245 218 245 268 257 ... 256 257 324 283 281
#     green        (time, y, x) uint16 417 355 345 401 472 ... 383 387 451 382 388
#     blue         (time, y, x) uint16 230 214 199 235 249 ... 154 182 205 201 168
# Attributes:
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref

# %%
rgb(session2Quiz_ds, bands=['red', 'green', 'blue'],
   index=0, size=10)
